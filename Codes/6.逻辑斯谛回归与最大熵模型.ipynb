# %% [markdown]
# # 第 6 章 逻辑斯谛回归与最大熵模型
# ## 6.2 最大熵模型
# ### 例 6.1
# **假设随机变量$X$有5个取值$\{A,B, C, D, E\}$，要估计取各个值的概率$P(A),P(B),P(C),P(D),P(E)$**.
# **解：由题意得，估计概率值满足约束：$P(A)+P(B)+P(C)+P(D)+P(E)=1 $**
#
# 满足，这个约束的概率分布有无穷多个。如果**没有任何其他信息**，仍要对概率分布进行估计，一个办法就是**认为这个分布中各个值的概率是相等的**：
# $$
# \begin{aligned}
# P(A)=P(B)=P(C)=P(D)=P(E)=\frac{1}{5}
# \end{aligned}
# $$
# 这种**概率相等**的认知表示了对**事实**的无知，因为没有更多的信息，这种判断是合理的。

# %% [markdown]
# ### 算法 6.1 改进的迭代尺度算法 IIS
#
# 输入：特征函数$f_1,f_2, \cdots,f_n$；经验分布$\hat P(X,Y)$，最大熵模型$P_w(y|x)$
#
# 输出：最优参数值$w^*_i$，最优模型$P_w^*$
#
# 1. 对所有$i \in \{1, 2, \cdots, n\}$，取**初值$w_i=0$**
#
# 2. 对每一个$i \in \{1, 2, \cdots, n\}$
#    - 令$\delta_i$是方程$\frac{\partial B(\delta|w)}{\partial \delta_i}=0$的解
#    - 更新$w_i$的值：$w_i \leftarrow w_i +\delta_i$
# 3. 如果不是所有的$w_i$都收敛，则重复步骤（2）
#
# 其中
# $$
# \begin{aligned}
# \frac{\partial B(\delta|w)}{\partial \delta_i}&=\sum_{x,y}\hat P(x,y)f_i(x,y)-\sum_x\hat P(x)\sum_y P_w(x,y)f_i(x,y)\exp(\delta_if^\#(x,y))
# \end{aligned}
# $$

# %% [markdown]
# ### 算法 6.2 最大熵模型学习得BFGS算法
# 输入：特征函数$f_1,f_2, \cdots, f_n$，经验分布$\hat P(x, y)$，目标函数$f(w)$，梯度$g(w)=\nabla f(w),\ f(w)=-\Psi(W)$，**精度要求$\epsilon$**。
#
# 输出：最优参数值$w^*$；最优模型$P_{w^*}(y|x)$
#
# （1）选定初始点$w^{(0)}$，取$B_0$为**正定对称矩阵**，置$k=0$；
#
# （2）计算$g_k = g(w^{(k)})$。若$||g_k||<\epsilon$，则**停止计算**，得$w^*=w^{(k)}$，否则转（3）
#
# （3）由$B_kp_k=-g_k$求出$p_k$；
#
# （4）**一维搜索**：求$\lambda_k$使得
# $$
# \begin{aligned}
# f(w^{(k)}+\lambda_kp_k)=\mathop\min\limits_{\lambda\ge 0}f(w^{(k)}+\lambda _kp)
# \end{aligned}
# $$
# （5）置$w^{(k+1)}=w^{(k)}+\lambda_k p_k$；
#
# （6）计算$g_{k+1}=g(w^{(k+1)})$，若$||g_{k+1}||<\epsilon$，则**停止计算**，得$w^* = w^{(k+1)}$。否则，按下式求出$B_{k+1}$：
# $$
# \begin{aligned}
# B_{k+1}=B_k +\frac{y_ky_k^T}{y_k^T\delta_k}-\frac{B_k\delta_k\delta_k^TB_k}{\delta^T_kB_k\delta_k}
# \end{aligned}
# $$
# 其中，$y_k= g_{k+1}-g_k,\delta_k=w^{(k+1)}-w^{(k)}$
#
# （7）置$k=k+1$，转（3）。

# %%
# [Reference](https://blog.csdn.net/weixin_44972997/article/details/117980281)

import numpy as np
# 目标优化函数
fun = lambda x : 0.5 * x[0] ** 2 + x[1] ** 2 - x[0] * x[1] - 2 * x[0]
# 对定义得函数求梯度值，数据放入mat矩阵中
def fungradient(x):
    x = np.array(x)
    partial_x_0 = x[0][0] - x[1][0] - 2
    partial_x_1 = -1.0 * x[0][0] + 2.0 * x[1][0]
    # 将数据解释为矩阵
    gradient = np.mat([partial_x_0, partial_x_1])
    return gradient

def BGFS(fun, fungradient, x0, epsilon):
    # 迭代次数
    iteration = 5000
    # 步长
    step = 0.45
    # 常数 在 [0, 0.5] 之间
    sigma = 0.3
    # 第k次迭代
    k = 0
    # 正定矩阵 Bk: 初始值为单位矩阵
    Bk = np.mat([[1.0, 0.0], [0.0, 1.0]])
    while k < iteration :
        # (2) 计算 gk = g(w^k)
        gk = fungradient(x0)
        # 如果 范数小于epsilon， 则停止计算，得 w^* = w^(k)
        if np.linalg.norm(gk) < epsilon:
            break
        # (3) 由 Bk × pk = - gk ————>  pk = (Bk.I) × (-gk.T)
        pk = -Bk.I.dot(gk.T)
        # (4) 一维搜索: 求 λk 使得 f(w^k + λk×pk) = min f(wk + λp_k)
        m = 0
        mk = 0
        while m < 30 :
            if fun(x0 + (step ** m ) * pk) < fun(x0) + sigma * (step ** m) * gk.dot(pk):
                mk = m
                break
            m = m + 1
        # (5) w^(k+1) = w^k + λ_k × p_k
        x = x0 + (step ** mk) * pk
        # (6) 计算 g_(k+1) = g(w^(k+1))
        if np.linalg.norm(fungradient(x)) < epsilon:
            break
        difg = fungradient(x) - gk
        delta = x - x0
        Bk = Bk - (Bk * delta * delta.T * Bk) / (delta.T * Bk * delta) + (difg.T * difg) / (difg * delta)
        k = k + 1
        x0 = x
        print("第 {0} 次迭代，参数值为：{1}, 函数值为：{2}".format(k, x0.T, fun(x0)))
    return x, k

# %%
# 选择初始点
x0 = np.array([[1], [1]])
# BFGS迭代
x, k = BGFS(fun, fungradient, x0, 1e-6)
print("---------------------------------------")
print("迭代次数为 {0} , 最优点为 {1} , 最小值为 {2}".format(k, x.T, fun(x)))
# Out:
# 第 1 次迭代，参数值为：[[1.9  0.55]], 函数值为：[[-2.7375]]
# 第 2 次迭代，参数值为：[[3.   1.25]], 函数值为：[[-3.6875]]
# 第 3 次迭代，参数值为：[[4.00110947 1.99852071]], 函数值为：[[-3.99999556]]
# 第 4 次迭代，参数值为：[[4.00003401 1.99998268]], 函数值为：[[-4.]]
# ---------------------------------------
# 迭代次数为 4 , 最优点为 [[4.00000001 2.00000001]] , 最小值为 [[-4.]]

# %% [markdown]
# ## 习题
# ### 6.1 确认逻辑斯谛分布属于指数分布族
# [Reference](https://blog.csdn.net/qq_41562704/article/details/99757050)
# #### 指数分布族
# **指数分布族中的分布形式如下**：
# $$
# \begin{aligned}
# p(x|\eta)=h(x)\exp\{\eta^TT(x)-A(\eta)\}
# \end{aligned}
# $$
# 其中：
# - $\eta$表示自然参数(normal parameter)，可以是向量形式
# - $T(x)$为充分统计量（sufficient statistic）
# - $A(\eta)$为累积函数（accumulate function）,作用是确保概率和为1
# - $h(x)$为 潜在度量（underlying measure）
# #### (1)证明：二项逻辑斯谛回归
# 二项逻辑斯蒂回归模型如下：
# $$
# \begin{aligned}
# P(Y=0|x) &= \frac{1}{1+\exp(wx)}\\
# P(Y=1|x) &= \frac{\exp(w\cdot x)}{1+\exp(w\cdot x)}
# \end{aligned}
# $$
# 可以组合为
# $$
# \begin{aligned}
# P(Y=y|x)&=P(Y=0|x)^{(1-y)}\cdot P(Y=1)^y\\
# &=\frac{1}{1+\exp(wx)}^{(1-y)}\cdot \frac{\exp(w\cdot x)}{1+\exp(w\cdot x)}^y
# \end{aligned}
# $$
# 对二项逻辑斯蒂回归模型的右端进行改造，改为以$e$为底的形式, 且令$\pi(x) = \exp(w\cdot x)$
# $$
# \begin{aligned}
# P(Y=y|x)&=\exp\left\{\log \left(\frac{1}{1+\pi(x)}^{(1-y)}\cdot \frac{\pi(x)}{1+\pi(x)}^y\right)\right\}\\
# &=\exp\left\{y\log\pi(x)-\log(1+\pi(x))\right\}
# \end{aligned}
# $$
# 根据此式，可得
# $$
# \begin{aligned}
# h(y) &= 1\\
# T(y) &= y \\
# \eta &= \log \pi(x)\\
# A(\eta) &= \log(1+\pi(x))
# \end{aligned}
# $$
# **所以，可证二项逻辑斯蒂回归是指数分布族**
# #### (2) 证明： 多项逻辑斯谛回归模型
# 多项逻辑斯谛回归模型简写如下
# $$
# \begin{aligned}
# P(Y=k|x)&=\frac{\exp(w_k\cdot x)}{1+\sum_{k=1}^{K-1}\exp(w_k \cdot x)}, k=1,2,\cdots, K-1\\
# P(Y=K|x)&=\frac{1}{1+\sum_{k=1}^{K-1}\exp(w_k \cdot x)}
# \end{aligned}
# $$
# 令$\pi(x)=\sum_{k=1}^{K-1}\exp(w_k \cdot x) + 1$，则多项逻辑斯谛回归模型表示如下
# $$
# \begin{aligned}
# P(Y|x)&=\left[\frac{\exp(w_k + x)}{\pi(x)}\right]^{f(y)}\cdot \left[\frac{1}{\pi(x)}\right]^{1-f(y)}\\
# f(y)&=\left\{ \begin{array}{l}
# 0, y=K\\
# 1, y<K
# \end{array} \right.
# \end{aligned}
# $$
# 对右端进行改造，以$e$为底
# $$
# \begin{aligned}
# P(Y|x)&=\exp\left\{f(y)\log\exp(w_k\cdot x)+f(y)\log \pi(x)\right\}\\
# &=\exp\left\{f(y)(\log\exp(w_k\cdot x)+\log \pi(x))\right\}
# \end{aligned}
# $$
# 根据此式，可得
# $$
# \begin{aligned}
# h(y) &= 1\\
# T(y) &= f(y) \\
# \eta &= \log \pi(x)+\log\exp(w_k \cdot x)\\
# A(\eta) &= 0
# \end{aligned}
# $$
# **所以，可证多项逻辑斯蒂回归是指数分布族**
# **综上所述，逻辑斯谛分布是指数分布族**

# %% [markdown]
# ### 6.2 写出逻辑斯谛回归模型学习的梯度下降算法
# 输入：训练数据集$T=\{(x_1,y_1),(x_2,y_2),\cdots,(x_N, y_N)\},x_i \in R^n,\ \ y_i=\{0, 1\}$，学习率：$\lambda$
# 输出：$w$
# （1）选取初值 $w_0$，$k=0$
# （2）二项逻辑斯谛回归模型的对数似然函数为
# $
# L(w_k)=\sum_{i=1}^N \{y_i(w_k\cdot x)-\log(1+\exp(w_k \cdot x))\}
# $
# （3）对数似然函数求偏导:$\frac{\partial L}{\partial w_k}$
# （4）更新偏导：$w_k \leftarrow w_k + \lambda \cdot \frac{\partial L}{\partial w_k}$
# （5）转置（2），同时更新$k=k+1$，直到满足条件为止。
#
# ### 6.3 写出最大熵模型学习的DFP算法。（关于一般的DFP算法参见附录B）
# #### DFP 算法
# 输入：目标函数$f(x)$，梯度$g(x)=\nabla f(x)$，精度要求为$\epsilon$
# 输出：$f(x)$的极小点$x^*$
# （1）选定初始点$x^{(0)}$，取$G_0$为正定对阵矩阵，置$k=0$
# （2）计算$g_k = g(x^{(k)})$。若$||g_k||<\epsilon$，则停止计算，得近似解$x^*=x^{(k)}$；否则转（3）
# （3）置$p_k = -G_k \cdot g_k$
# （4）**一维搜索**：求$\lambda_k$使得：
# $$
# \begin{aligned}
# f(x^{(k)}+\lambda_k\cdot p_k)=\mathop\min\limits_{\lambda \ge 0} f(x^{(k)}+\lambda\cdot p_k)
# \end{aligned}
# $$
# （5）置$x^{(k+1)}=x^{(k)}+\lambda_k \cdot p_k$
# （6）计算$g_{k+1}=g(x^{(k+1)})$。如果$||g_{k+1}||<\epsilon$，则停止计算，得到近似解$x^*=x^{(k+1)}$；否则，按照以下的方式计算**正定对阵矩阵$G_{k+1}$**
# $$
# \begin{aligned}
# G_{k+1}=G_k + \frac{\delta_k \delta_k^T}{\delta_k^Ty_k} - \frac{G_ky_ky_k^TG_k}{y_k^TG_ky_k}
# \end{aligned}
# $$
# （7）置$k=k+1$，转（3）。

# %%
import numpy as np
# 目标优化函数
fun = lambda x : 0.5 * x[0] ** 2 + x[1] ** 2 - x[0] * x[1] - 2 * x[0]
# 对定义得函数求梯度值，数据放入mat矩阵中
def g(x):
    x = np.array(x)
    partial_x_0 = x[0][0] - x[1][0] - 2
    partial_x_1 = -1.0 * x[0][0] + 2.0 * x[1][0]
    # 将数据解释为矩阵
    gradient = np.mat([[partial_x_0] ,[partial_x_1]])
    return gradient

def DFP(fun, g, x0, epsilon):
    # 迭代次数
    iteration = 5000
    # 步长
    step = 0.45
    # 常数 在 [0, 0.5] 之间
    sigma = 0.3
    # 第k次迭代
    k = 0
    # 正定矩阵 Bk: 初始值为单位矩阵
    Gk = np.mat([[1.0, 0.0], [0.0, 1.0]])
    while k < iteration :
        # (2) 计算 gk = g(w^k)
        gk = g(x0)
        # 如果 范数小于epsilon， 则停止计算，得 w^* = w^(k)
        if np.linalg.norm(gk) < epsilon:
            break
        # (3) 由 Gk × pk = - gk ————>  pk = (Bk.I) × (-gk.T)
        pk = -Gk.dot(gk)
        # (4) 一维搜索: 求 λk 使得 f(w^k + λk×pk) = min f(wk + λp_k)
        m = 0
        mk = 0
        minf = 1e10
        while m < 100 :
            if fun(x0 + (step ** m ) * pk) < minf:
                minf = fun(x0 + (step ** m ) * pk)
                mk = m
            m = m + 1
        # (5) w^(k+1) = w^k + λ_k × p_k
        x = x0 + (step ** mk) * pk
        # (6) 计算 g_(k+1) = g(w^(k+1))
        if np.linalg.norm(g(x)) < epsilon:
            break
        y = g(x) - gk
        delta = x - x0
        Gk = Gk + (delta * delta.T) / (delta.T * y) + (Gk * y * y.T * Gk) / (y.T * Gk * y)
        k = k + 1
        x0 = x
        print("第 {0} 次迭代，参数值为：{1}, 函数值为：{2}".format(k, x0.T, fun(x0)))
    return x, k

# %%
# 选择初始点
x0 = np.array([[1], [1]])
# BFGS迭代
x, k = DFP(fun, g, x0, 1e-6)
print("---------------------------------------")
print("迭代次数为 {0} , 最优点为 {1} , 最小值为 {2}".format(k, x.T, fun(x)))
# Out:
# 第 1 次迭代，参数值为：[[1.9  0.55]], 函数值为：[[-2.7375]]
# 第 2 次迭代，参数值为：[[2.5 1.5]], 函数值为：[[-3.375]]
# 第 3 次迭代，参数值为：[[2.79760386 1.20335729]], 函数值为：[[-3.60036227]]
# 第 4 次迭代，参数值为：[[2.86630793 1.56267719]], 函数值为：[[-3.66190931]]
# 第 5 次迭代，参数值为：[[2.98556361 1.38724614]], 函数值为：[[-3.73159193]]
# 第 6 次迭代，参数值为：[[3.48039968 1.51183355]], 函数值为：[[-3.88035272]]
# 第 7 次迭代，参数值为：[[3.42561888 1.61513764]], 函数值为：[[-3.9079818]]
# 第 8 次迭代，参数值为：[[3.40601933 1.65721013]], 函数值为：[[-3.90969914]]
# 第 9 次迭代，参数值为：[[3.42013852 1.63618599]], 函数值为：[[-3.91048143]]
# 第 10 次迭代，参数值为：[[3.41571157 1.64549445]], 函数值为：[[-3.91076282]]
# 第 11 次迭代，参数值为：[[3.42415749 1.63434218]], 函数值为：[[-3.91105838]]
# 第 12 次迭代，参数值为：[[3.4182206  1.64500288]], 函数值为：[[-3.91127342]]
# 第 13 次迭代，参数值为：[[3.42752264 1.63235663]], 函数值为：[[-3.91144069]]
# 第 14 次迭代，参数值为：[[3.42115621 1.64350686]], 函数值为：[[-3.91173642]]
# 第 15 次迭代，参数值为：[[3.41936103 1.64669793]], 函数值为：[[-3.91174779]]
# 第 16 次迭代，参数值为：[[3.42054653 1.64466325]], 函数值为：[[-3.91175375]]
# 第 17 次迭代，参数值为：[[3.41997844 1.64566562]], 函数值为：[[-3.91175622]]
# 第 18 次迭代，参数值为：[[3.42043056 1.64489167]], 函数值为：[[-3.91175764]]
# 第 19 次迭代，参数值为：[[3.42011014 1.64545224]], 函数值为：[[-3.91175841]]
# 第 20 次迭代，参数值为：[[3.42051336 1.64476343]], 函数值为：[[-3.91175944]]
# 第 21 次迭代，参数值为：[[3.42018384 1.64533772]], 函数值为：[[-3.9117602]]
# 第 22 次迭代，参数值为：[[3.42005451 1.64556411]], 函数值为：[[-3.91176031]]
# 第 23 次迭代，参数值为：[[3.42021503 1.64528485]], 函数值为：[[-3.91176037]]
# 第 24 次迭代，参数值为：[[3.4201226 1.6454459]], 函数值为：[[-3.9117604]]
# 第 25 次迭代，参数值为：[[3.42016228 1.64537686]], 函数值为：[[-3.91176041]]
# 第 26 次迭代，参数值为：[[3.42013622 1.64542229]], 函数值为：[[-3.91176042]]
# 第 27 次迭代，参数值为：[[3.42015373 1.6453918 ]], 函数值为：[[-3.91176042]]
# 第 28 次迭代，参数值为：[[3.42012444 1.64544292]], 函数值为：[[-3.91176043]]
# 第 29 次迭代，参数值为：[[3.42014894 1.64540026]], 函数值为：[[-3.91176043]]
# 第 30 次迭代，参数值为：[[3.42015522 1.64538933]], 函数值为：[[-3.91176043]]
# 第 31 次迭代，参数值为：[[3.42015102 1.64539665]], 函数值为：[[-3.91176043]]
# 第 32 次迭代，参数值为：[[3.4201558  1.64538832]], 函数值为：[[-3.91176043]]
# 第 33 次迭代，参数值为：[[3.42015166 1.64539554]], 函数值为：[[-3.91176043]]
# 第 34 次迭代，参数值为：[[3.4201539  1.64539162]], 函数值为：[[-3.91176043]]
# 第 35 次迭代，参数值为：[[3.4201525  1.64539407]], 函数值为：[[-3.91176043]]
# 第 36 次迭代，参数值为：[[3.42015701 1.64538622]], 函数值为：[[-3.91176043]]
# 第 37 次迭代，参数值为：[[3.42015328 1.6453927 ]], 函数值为：[[-3.91176043]]
# 第 38 次迭代，参数值为：[[3.42015273 1.64539367]], 函数值为：[[-3.91176043]]
# 第 39 次迭代，参数值为：[[3.42015245 1.64539416]], 函数值为：[[-3.91176043]]
# 第 40 次迭代，参数值为：[[3.42015273 1.64539367]], 函数值为：[[-3.91176043]]
# 第 41 次迭代，参数值为：[[3.4201525  1.64539407]], 函数值为：[[-3.91176043]]
# 第 42 次迭代，参数值为：[[3.4201526 1.6453939]], 函数值为：[[-3.91176043]]
# 第 43 次迭代，参数值为：[[3.42015247 1.64539412]], 函数值为：[[-3.91176043]]
# 第 44 次迭代，参数值为：[[3.42015253 1.64539401]], 函数值为：[[-3.91176043]]
# 第 45 次迭代，参数值为：[[3.4201526  1.64539389]], 函数值为：[[-3.91176043]]
# 第 46 次迭代，参数值为：[[3.42015256 1.64539397]], 函数值为：[[-3.91176043]]
# 第 47 次迭代，参数值为：[[3.42015253 1.64539401]], 函数值为：[[-3.91176043]]
# 第 48 次迭代，参数值为：[[3.42015256 1.64539397]], 函数值为：[[-3.91176043]]
# 第 49 次迭代，参数值为：[[3.42015254 1.645394  ]], 函数值为：[[-3.91176043]]
# 第 50 次迭代，参数值为：[[3.42015254 1.645394  ]], 函数值为：[[-3.91176043]]
# 第 51 次迭代，参数值为：[[3.42015254 1.645394  ]], 函数值为：[[-3.91176043]]
# 第 52 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 53 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 54 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 55 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 56 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 57 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 58 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 59 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 60 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 61 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# C:\Users\LiangHao\AppData\Local\Temp\ipykernel_20932\29933237.py:48: RuntimeWarning: invalid value encountered in true_divide
#   Gk = Gk + (delta * delta.T) / (delta.T * y) + (Gk * y * y.T * Gk) / (y.T * Gk * y)
# 第 62 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 63 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 64 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 65 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 66 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 67 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 68 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 69 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 70 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 71 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 72 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 73 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 74 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 75 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 76 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 77 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 78 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 79 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 80 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 81 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 82 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 83 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 84 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 85 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 86 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 87 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 88 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 89 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 90 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 91 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 92 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 93 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 94 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 95 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 96 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 97 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 98 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 99 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 100 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 101 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 102 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 103 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 104 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 105 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 106 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 107 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 108 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 109 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 110 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 111 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 112 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 113 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 114 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 115 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 116 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 117 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 118 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 119 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 120 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 121 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 122 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 123 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 124 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 125 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 126 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 127 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 128 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 129 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 130 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 131 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 132 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 133 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 134 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 135 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 136 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 137 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 138 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 139 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 140 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 141 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 142 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 143 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 144 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 145 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 146 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 147 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 148 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 149 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 150 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 151 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 152 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 153 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 154 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 155 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 156 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 157 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 158 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 159 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 160 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 161 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 162 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 163 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 164 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 165 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 166 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 167 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 168 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 169 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 170 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 171 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 172 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 173 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 174 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 175 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 176 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 177 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 178 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 179 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 180 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 181 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 182 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 183 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 184 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 185 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 186 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 187 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 188 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 189 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 190 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 191 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 192 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 193 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 194 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 195 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 196 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 197 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 198 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 199 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 200 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 201 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 202 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 203 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 204 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 205 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 206 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 207 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 208 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 209 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 210 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 211 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 212 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 213 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 214 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 215 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 216 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 217 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 218 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 219 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 220 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 221 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 222 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 223 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 224 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 225 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 226 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 227 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 228 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 229 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 230 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 231 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 232 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 233 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 234 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 235 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 236 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 237 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 238 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 239 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 240 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 241 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 242 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 243 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 244 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 245 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 246 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 247 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 248 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 249 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 250 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 251 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 252 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 253 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 254 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 255 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 256 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 257 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 258 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 259 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 260 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 261 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 262 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 263 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 264 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 265 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 266 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 267 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 268 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 269 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 270 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 271 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 272 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 273 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 274 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 275 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 276 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 277 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 278 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 279 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 280 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 281 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 282 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 283 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 284 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 285 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 286 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 287 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 288 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 289 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 290 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 291 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 292 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 293 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 294 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 295 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 296 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 297 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 298 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 299 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 300 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 301 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 302 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 303 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 304 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 305 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 306 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 307 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 308 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 309 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 310 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 311 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 312 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 313 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 314 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 315 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 316 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 317 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 318 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 319 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 320 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 321 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 322 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 323 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 324 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 325 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 326 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 327 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 328 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 329 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 330 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 331 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 332 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 333 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 334 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 335 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 336 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 337 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 338 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 339 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 340 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 341 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 342 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 343 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 344 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 345 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 346 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 347 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 348 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 349 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 350 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 351 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 352 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 353 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 354 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 355 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 356 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 357 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 358 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 359 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 360 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 361 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 362 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 363 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 364 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 365 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 366 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 367 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 368 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 369 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 370 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 371 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 372 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 373 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 374 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 375 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 376 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 377 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 378 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 379 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 380 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 381 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 382 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 383 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 384 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 385 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 386 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 387 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 388 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 389 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 390 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 391 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 392 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 393 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 394 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 395 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 396 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 397 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 398 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 399 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 400 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 401 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 402 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 403 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 404 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 405 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 406 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 407 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 408 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 409 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 410 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 411 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 412 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 413 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 414 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 415 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 416 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 417 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 418 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 419 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 420 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 421 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 422 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 423 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 424 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 425 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 426 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 427 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 428 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 429 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 430 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 431 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 432 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 433 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 434 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 435 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 436 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 437 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 438 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 439 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 440 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 441 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 442 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 443 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 444 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 445 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 446 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 447 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 448 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 449 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 450 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 451 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 452 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 453 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 454 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 455 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 456 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 457 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 458 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 459 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 460 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 461 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 462 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 463 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 464 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 465 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 466 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 467 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 468 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 469 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 470 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 471 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 472 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 473 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 474 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 475 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 476 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 477 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 478 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 479 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 480 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 481 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 482 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 483 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 484 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 485 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 486 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 487 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 488 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 489 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 490 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 491 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 492 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 493 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 494 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 495 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 496 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 497 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 498 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 499 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 500 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 501 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 502 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 503 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 504 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 505 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 506 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 507 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 508 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 509 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 510 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 511 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 512 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 513 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 514 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 515 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 516 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 517 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 518 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 519 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 520 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 521 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 522 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 523 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 524 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 525 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 526 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 527 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 528 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 529 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 530 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 531 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 532 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 533 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 534 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 535 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 536 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 537 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 538 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 539 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 540 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 541 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 542 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 543 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 544 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 545 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 546 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 547 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 548 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 549 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 550 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 551 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 552 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 553 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 554 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 555 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 556 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 557 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 558 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 559 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 560 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 561 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 562 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 563 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 564 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 565 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 566 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 567 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 568 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 569 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 570 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 571 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 572 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 573 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 574 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 575 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 576 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 577 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 578 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 579 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 580 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 581 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 582 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 583 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 584 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 585 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 586 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 587 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 588 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 589 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 590 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 591 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 592 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 593 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 594 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 595 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 596 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 597 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 598 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 599 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 600 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 601 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 602 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 603 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 604 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 605 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 606 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 607 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 608 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 609 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 610 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 611 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 612 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 613 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 614 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 615 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 616 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 617 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 618 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 619 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 620 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 621 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 622 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 623 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 624 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 625 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 626 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 627 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 628 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 629 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 630 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 631 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 632 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 633 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 634 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 635 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 636 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 637 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 638 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 639 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 640 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 641 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 642 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 643 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 644 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 645 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 646 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 647 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 648 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 649 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 650 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 651 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 652 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 653 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 654 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 655 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 656 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 657 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 658 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 659 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 660 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 661 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 662 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 663 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 664 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 665 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 666 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 667 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 668 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 669 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 670 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 671 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 672 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 673 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 674 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 675 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 676 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 677 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 678 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 679 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 680 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 681 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 682 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 683 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 684 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 685 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 686 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 687 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 688 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 689 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 690 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 691 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 692 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 693 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 694 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 695 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 696 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 697 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 698 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 699 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 700 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 701 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 702 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 703 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 704 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 705 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 706 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 707 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 708 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 709 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 710 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 711 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 712 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 713 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 714 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 715 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 716 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 717 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 718 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 719 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 720 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 721 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 722 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 723 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 724 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 725 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 726 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 727 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 728 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 729 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 730 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 731 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 732 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 733 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 734 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 735 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 736 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 737 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 738 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 739 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 740 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 741 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 742 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 743 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 744 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 745 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 746 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 747 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 748 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 749 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 750 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 751 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 752 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 753 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 754 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 755 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 756 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 757 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 758 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 759 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 760 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 761 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 762 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 763 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 764 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 765 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 766 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 767 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 768 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 769 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 770 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 771 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 772 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 773 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 774 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 775 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 776 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 777 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 778 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 779 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 780 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 781 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 782 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 783 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 784 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 785 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 786 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 787 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 788 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 789 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 790 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 791 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 792 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 793 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 794 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 795 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 796 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 797 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 798 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 799 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 800 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 801 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 802 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 803 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 804 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 805 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 806 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 807 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 808 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 809 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 810 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 811 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 812 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 813 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 814 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 815 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 816 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 817 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 818 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 819 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 820 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 821 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 822 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 823 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 824 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 825 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 826 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 827 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 828 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 829 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 830 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 831 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 832 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 833 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 834 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 835 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 836 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 837 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 838 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 839 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 840 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 841 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 842 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 843 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 844 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 845 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 846 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 847 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 848 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 849 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 850 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 851 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 852 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 853 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 854 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 855 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 856 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 857 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 858 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 859 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 860 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 861 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 862 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 863 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 864 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 865 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 866 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 867 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 868 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 869 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 870 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 871 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 872 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 873 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 874 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 875 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 876 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 877 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 878 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 879 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 880 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 881 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 882 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 883 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 884 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 885 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 886 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 887 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 888 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 889 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 890 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 891 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 892 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 893 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 894 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 895 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 896 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 897 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 898 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 899 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 900 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 901 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 902 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 903 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 904 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 905 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 906 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 907 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 908 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 909 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 910 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 911 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 912 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 913 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 914 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 915 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 916 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 917 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 918 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 919 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 920 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 921 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 922 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 923 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 924 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 925 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 926 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 927 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 928 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 929 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 930 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 931 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 932 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 933 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 934 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 935 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 936 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 937 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 938 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 939 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 940 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 941 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 942 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 943 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 944 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 945 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 946 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 947 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 948 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 949 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 950 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 951 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 952 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 953 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 954 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 955 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 956 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 957 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 958 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 959 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 960 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 961 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 962 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 963 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 964 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 965 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 966 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 967 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 968 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 969 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 970 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 971 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 972 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 973 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 974 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 975 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 976 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 977 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 978 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 979 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 980 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 981 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 982 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 983 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 984 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 985 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 986 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 987 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 988 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 989 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 990 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 991 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 992 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 993 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 994 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 995 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 996 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 997 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 998 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 999 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1000 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1001 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1002 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1003 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1004 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1005 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1006 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1007 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1008 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1009 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1010 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1011 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1012 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1013 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1014 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1015 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1016 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1017 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1018 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1019 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1020 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1021 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1022 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1023 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1024 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1025 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1026 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1027 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1028 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1029 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1030 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1031 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1032 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1033 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1034 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1035 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1036 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1037 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1038 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1039 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1040 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1041 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1042 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1043 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1044 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1045 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1046 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1047 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1048 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1049 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1050 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1051 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1052 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1053 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1054 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1055 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1056 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1057 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1058 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1059 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1060 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1061 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1062 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1063 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1064 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1065 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1066 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1067 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1068 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1069 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1070 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1071 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1072 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1073 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1074 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1075 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1076 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1077 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1078 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1079 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1080 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1081 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1082 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1083 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1084 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1085 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1086 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1087 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1088 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1089 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1090 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1091 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1092 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1093 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1094 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1095 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1096 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1097 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1098 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1099 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1100 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1101 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1102 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1103 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1104 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1105 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1106 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1107 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1108 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1109 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1110 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1111 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1112 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1113 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1114 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1115 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1116 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1117 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1118 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1119 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1120 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1121 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1122 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1123 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1124 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1125 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1126 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1127 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1128 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1129 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1130 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1131 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1132 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1133 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1134 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1135 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1136 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1137 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1138 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1139 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1140 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1141 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1142 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1143 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1144 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1145 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1146 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1147 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1148 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1149 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1150 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1151 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1152 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1153 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1154 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1155 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1156 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1157 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1158 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1159 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1160 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1161 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1162 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1163 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1164 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1165 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1166 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1167 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1168 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1169 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1170 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1171 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1172 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1173 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1174 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1175 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1176 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1177 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1178 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1179 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1180 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1181 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1182 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1183 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1184 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1185 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1186 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1187 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1188 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1189 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1190 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1191 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1192 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1193 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1194 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1195 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1196 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1197 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1198 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1199 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1200 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1201 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1202 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1203 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1204 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1205 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1206 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1207 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1208 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1209 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1210 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1211 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1212 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1213 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1214 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1215 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1216 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1217 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1218 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1219 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1220 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1221 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1222 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1223 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1224 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1225 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1226 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1227 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1228 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1229 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1230 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1231 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1232 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1233 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1234 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1235 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1236 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1237 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1238 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1239 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1240 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1241 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1242 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1243 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1244 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1245 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1246 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1247 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1248 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1249 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1250 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1251 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1252 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1253 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1254 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1255 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1256 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1257 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1258 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1259 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1260 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1261 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1262 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1263 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1264 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1265 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1266 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1267 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1268 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1269 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1270 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1271 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1272 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1273 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1274 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1275 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1276 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1277 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1278 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1279 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1280 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1281 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1282 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1283 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1284 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1285 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1286 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1287 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1288 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1289 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1290 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1291 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1292 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1293 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1294 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1295 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1296 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1297 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1298 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1299 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1300 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1301 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1302 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1303 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1304 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1305 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1306 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1307 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1308 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1309 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1310 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1311 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1312 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1313 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1314 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1315 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1316 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1317 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1318 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1319 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1320 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1321 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1322 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1323 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1324 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1325 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1326 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1327 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1328 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1329 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1330 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1331 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1332 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1333 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1334 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1335 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1336 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1337 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1338 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1339 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1340 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1341 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1342 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1343 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1344 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1345 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1346 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1347 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1348 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1349 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1350 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1351 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1352 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1353 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1354 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1355 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1356 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1357 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1358 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1359 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1360 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1361 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1362 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1363 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1364 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1365 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1366 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1367 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1368 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1369 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1370 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1371 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1372 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1373 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1374 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1375 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1376 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1377 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1378 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1379 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1380 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1381 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1382 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1383 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1384 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1385 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1386 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1387 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1388 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1389 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1390 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1391 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1392 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1393 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1394 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1395 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1396 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1397 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1398 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1399 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1400 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1401 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1402 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1403 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1404 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1405 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1406 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1407 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1408 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1409 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1410 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1411 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1412 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1413 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1414 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1415 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1416 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1417 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1418 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1419 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1420 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1421 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1422 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1423 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1424 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# 第 1425 次迭代，参数值为：[[nan nan]], 函数值为：[[nan]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [77], in <cell line: 4>()
#       2 x0 = np.array([[1], [1]])
#       3 # BFGS迭代
# ----> 4 x, k = DFP(fun, g, x0, 1e-6)
#       5 print("---------------------------------------")
#       6 print("迭代次数为 {0} , 最优点为 {1} , 最小值为 {2}".format(k, x.T, fun(x)))
#
# Input In [76], in DFP(fun, g, x0, epsilon)
#      46 y = g(x) - gk
#      47 delta = x - x0
# ---> 48 Gk = Gk + (delta * delta.T) / (delta.T * y) + (Gk * y * y.T * Gk) / (y.T * Gk * y)
#      49 k = k + 1
#      50 x0 = x
#
# File E:\Application\Anconda\envs\pytorch_11_3\lib\site-packages\numpy\matrixlib\defmatrix.py:218, in matrix.__mul__(self, other)
#     215 def __mul__(self, other):
#     216     if isinstance(other, (N.ndarray, list, tuple)) :
#     217         # This promotes 1-D vectors to row vectors
# --> 218         return N.dot(self, asmatrix(other))
#     219     if isscalar(other) or not hasattr(other, '__rmul__') :
#     220         return N.dot(self, other)
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
